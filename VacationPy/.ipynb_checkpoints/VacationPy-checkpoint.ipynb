# %%
import gmaps
import pandas as pd
import requests
import json

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Creating weather stats dataframe from data in WeatherPy assignment
weather = pd.read_csv('../WeatherPy/retrieved_weather_data.csv')
weather.dropna(inplace = True)
weather.head()
# Out:
#            Name  Latitude (°)  Longitude (°)  Temperature (F)  Humidity (%)  \
# 0       Aklavik         68.22        -135.01            35.60            93
# 1     Sistranda         63.73           8.83            53.60            93
# 2  Punta Arenas        -53.15         -70.92            42.39            81
# 3      Manakara        -22.13          48.02            64.31            89
# 4        Albany         42.60         -73.97            41.67            58
#
#    Wind Speed (mph)  Cloudiness (%)
# 0              4.70              90
# 1             11.41              75
# 2             12.75              98
# 3              7.02               0
# 4              3.91               0

# %%
# Storing locations
locations = weather[["Latitude (°)", "Longitude (°)"]]
locations
lat_long = list(zip(locations['Latitude (°)'],locations['Longitude (°)']))
weather['Lat_Long'] = lat_long
weather.head(5)
lat_long
# Out:
# [(68.22, -135.01),
#  (63.73, 8.83),
#  (-53.15, -70.92),
#  (-22.13, 48.02),
#  (42.6, -73.97),
#  (-46.19, 168.86),
#  (72.79, -56.15),
#  (-33.65, 115.33),
#  (-28.65, 153.62),
#  (5.84, 118.12),
#  (50.6, 97.52),
#  (68.75, 161.3),
#  (59.7, 30.79),
#  (37.37, 118.02),
#  (65.28, -126.83),
#  (-21.21, -159.78),
#  (71.29, -156.79),
#  (-20.23, 164.02),
#  (-34.42, 19.23),
#  (-35.34, 143.55),
#  (70.47, -68.59),
#  (35.73, 140.83),
#  (24.76, 71.77),
#  (-21.36, 55.77),
#  (1.49, 124.85),
#  (-46.6, 168.33),
#  (-46.28, 169.85),
#  (36.5, -5.75),
#  (40.81, 114.88),
#  (-24.79, -50.01),
#  (-33.93, 18.42),
#  (45.04, 41.97),
#  (-35.35, 150.47),
#  (-23.7, 133.88),
#  (35.13, 140.3),
#  (-2.57, 150.8),
#  (-28.55, 16.43),
#  (30.48, -115.95),
#  (73.51, 80.55),
#  (20.2, 1.01),
#  (-33.59, 26.89),
#  (62.46, -114.35),
#  (-16.48, -151.75),
#  (-20.41, 57.7),
#  (42.1, -79.24),
#  (-0.74, -90.35),
#  (-23.12, -134.97),
#  (62.27, 21.38),
#  (-2.92, -39.92),
#  (-31.43, 152.92),
#  (-26.79, -60.44),
#  (51.13, 93.6),
#  (39.82, 109.98),
#  (57.05, -135.33),
#  (60.92, -46.05),
#  (-9.8, -139.03),
#  (-20.95, -43.81),
#  (50.91, 106.24),
#  (41.37, -73.41),
#  (19.22, -104.7),
#  (-24.87, 113.63),
#  (70.37, 31.11),
#  (-23.78, -45.36),
#  (42.56, -2.36),
#  (43.36, 76.86),
#  (9.33, -82.25),
#  (-32.03, -52.1),
#  (-15.43, -74.62),
#  (22.08, -159.32),
#  (71.97, 102.5),
#  (68.82, -51.19),
#  (-21.2, -175.2),
#  (2.74, 23.78),
#  (-25.24, 130.99),
#  (60.37, 93.04),
#  (-2.54, -57.76),
#  (-10.26, -40.2),
#  (69.45, -133.04),
#  (69.38, 178.42),
#  (39.03, -92.33),
#  (-28.77, 114.6),
#  (17.08, 122.42),
#  (6.3, -10.8),
#  (68.05, 166.44),
#  (-9.88, -56.09),
#  (57.11, 12.25),
#  (-14.9, 50.28),
#  (62.97, 23.01),
#  (38.93, 100.45),
#  (47.67, -52.73),
#  (69.24, 19.23),
#  (60.95, 25.93),
#  (8.37, -4.43),
#  (20.71, 70.98),
#  (49.42, 31.92),
#  (19.73, 96.22),
#  (47.6, -53.26),
#  (25.77, -80.19),
#  (34.72, -77.32),
#  (24.8, 125.28),
#  (41.76, 86.15),
#  (-38.95, -68.06),
#  (13.59, -89.83),
#  (56.91, 118.26),
#  (-20.74, 116.85),
#  (-3.99, -79.2),
#  (-20.05, 48.12),
#  (-29.95, -71.34),
#  (13.2, -16.73),
#  (55.34, -131.65),
#  (60.47, 166.1),
#  (32.63, -16.97),
#  (54.11, 11.9),
#  (36.4, -97.88),
#  (55.83, 34.27),
#  (61.94, 76.66),
#  (14.3, -91.92),
#  (-30.4, -56.47),
#  (39.51, 54.37),
#  (-41.87, -73.82),
#  (40.28, 97.2),
#  (-39.2, 173.88),
#  (-3.33, 128.92),
#  (-17.8, -63.17),
#  (29.27, 82.18),
#  (4.42, -7.35),
#  (-8.14, 159.59),
#  (35.96, -80.01),
#  (50.1, 118.04),
#  (66.04, -17.34),
#  (38.42, -121.42),
#  (-38.55, -58.74),
#  (35.02, -110.7),
#  (17.88, -76.41),
#  (67.8, 130.41),
#  (54.72, 135.31),
#  (16.58, 82.02),
#  (-8.68, 36.72),
#  (-8.01, -34.86),
#  (-34.48, -54.33),
#  (-44.49, 171.21),
#  (65.85, 74.49),
#  (37.1, -113.58),
#  (3.46, 8.55),
#  (14.69, -17.44),
#  (-20.1, 146.27),
#  (50.2, -66.38),
#  (37.34, -121.89),
#  (47.8, 67.71)]

# %%
# Filtering for desired weather conditions
good_weather = weather.loc[(weather['Temperature (F)'] > 70) & (weather['Cloudiness (%)'] < 50) & (weather['Humidity (%)'] < 50)]
good_weather.head(5)
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 39               Tessalit         20.20           1.01            87.42
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long
# 32             37             16.11              20  (-35.35, 150.47)
# 39             16              8.66               0      (20.2, 1.01)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)

# %%
# Adding column for nearest hotel
nearest_hotel = pd.DataFrame(good_weather)
nearest_hotel['Nearest_Hotel'] = ""
nearest_hotel['Global_Code'] = ""
nearest_hotel.head(5)
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 39               Tessalit         20.20           1.01            87.42
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long  \
# 32             37             16.11              20  (-35.35, 150.47)
# 39             16              8.66               0      (20.2, 1.01)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)
#
#     Nearest_Hotel Global_Code
# 32
# 39
# 92
# 130
# 157

# %%
# params dictionary to update each iteration

params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}

for index, row in nearest_hotel.iterrows():
    # get lat, lng from df
    lat = row["Latitude (°)"]
    lng = row["Longitude (°)"]
    
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    results = requests.get(base_url, params=params).json()    
    
    try:
        nearest_hotel.loc[index, "Nearest_Hotel"] = results["results"][0]["name"]
        nearest_hotel.loc[index, "Global_Code"] = results["results"][0]["plus_code"]['global_code']
        print(f"Successfully added, ", results["results"][0]["name"])
    
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        continue
# Out:
# Successfully added,  Sandpiper Motel
# Missing field/result... skipping.
# Successfully added,  Hampton Inn & Suites Pueblo-Southgate
# Successfully added,  ホテル コラソン
# Successfully added,  Hotel Fairmont Makkah Clock Royal Tower
# Successfully added,  Lamar Resort Abu Soma
# Successfully added,  Shingu UI Hotel
# Successfully added,  LOTTE HOTEL SEOUL
# Successfully added,  Hotel pousada santo onofre
# Successfully added,  ホテル松原屋
# Successfully added,  Marriott's Ko Olina Beach Club
# Successfully added,  San Ramon Marriott
# Successfully added,  Hometowne Inn
# Successfully added,  Batemans Bay Marina Resort
# Successfully added,  Mövenpick Hotel Qassim
# Successfully added,  Nag Aespen
# Successfully added,  ibis Styles Mt Isa Verona
# Successfully added,  The Esplanade Hotel
# Successfully added,  Expeditions Ténére voyages
# Successfully added,  ibis Styles Karratha
# Successfully added,  Holiday Inn Express & Suites Elk Grove Central - Hwy 99
# Successfully added,  Best Western Plus Winslow Inn
# Successfully added,  Best Western Plus Abbey Inn
# Successfully added,  Cattleman's Rest Motor Inn

# %%
nearest_hotel.head(5)
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 39               Tessalit         20.20           1.01            87.42
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long  \
# 32             37             16.11              20  (-35.35, 150.47)
# 39             16              8.66               0      (20.2, 1.01)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)
#
#                                Nearest_Hotel  Global_Code
# 32                           Sandpiper Motel  4RPGJFXG+87
# 39
# 92     Hampton Inn & Suites Pueblo-Southgate  85CQ698G+P6
# 130                                 ホテル コラソン  8Q6J8JW5+Q3
# 157  Hotel Fairmont Makkah Clock Royal Tower  7GHXCR9G+66

# %%
print(json.dumps(results, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0676956,
#                     "lng": 146.2605285
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.06652866970849,
#                         "lng": 146.2616240302915
#                     },
#                     "southwest": {
#                         "lat": -20.0692266302915,
#                         "lng": 146.2589260697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Cattleman's Rest Motor Inn",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116860246320032547466\">Craig Collins</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdMi6scpQ43X4MHpYyfc65Q1M0hBg-Ob0QS7sPJOLmN4c6K6AhFEFdzOVDRMqUC1piRltXkRfCUuJ3wt5XE1glY0QyBriCH4recxnjmTLKLII6M-il3ZnMqxn9iEMwmOeEhDOIvvVL1-d4JjRY2Qx4XITGhRbucbHraTUDJ-ms90ftYC9NJ2bZw",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJUckdD1he1GsRaW_OH7ox9Lw",
#             "plus_code": {
#                 "compound_code": "W7J6+W6 Grand Secret QLD, Australia",
#                 "global_code": "5RF8W7J6+W6"
#             },
#             "rating": 4,
#             "reference": "ChIJUckdD1he1GsRaW_OH7ox9Lw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 118,
#             "vicinity": "1 Bridge Street, Grand Secret"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0936111,
#                     "lng": 146.2613889
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0922690697085,
#                         "lng": 146.2627275302915
#                     },
#                     "southwest": {
#                         "lat": -20.0949670302915,
#                         "lng": 146.2600295697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png",
#             "name": "Charters Towers Tourist Park",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117929562188143778449\">Elizabeth Muir</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAkLK2fSsD2OJu8359gkqPmM0nh1MXI2JcsFeRajxlqjT9WSXCucuFyzrZ1XE_OFqo-YlC21kW7OVyp5De5CuuBbc_yqa_sCM0PojUbWXDXKq2HsLGHq9eEbxWBlhOBAsPEhABVbCYozyXXVnyEsaMi1yEGhQb4EDxsh3ArYeDZx48Ev9ODW9tGg",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ5bKviTle1GsR0d0lHEH1hIE",
#             "plus_code": {
#                 "compound_code": "W746+HH Mosman Park QLD, Australia",
#                 "global_code": "5RF8W746+HH"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ5bKviTle1GsR0d0lHEH1hIE",
#             "scope": "GOOGLE",
#             "types": [
#                 "park",
#                 "campground",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 227,
#             "vicinity": "37 Mount Leyshon Road, Mosman Park"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.06327959999999,
#                     "lng": 146.2835835
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0617124197085,
#                         "lng": 146.2849565802915
#                     },
#                     "southwest": {
#                         "lat": -20.0644103802915,
#                         "lng": 146.2822586197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Heritage Lodge Motel Charters Towers",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109806878440739102926\">Imelda Adamson Agars</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAg4yDP1MqaU-hvk9Ud3yBI57FX3th9ViEdt0NqNHWYcWjXhbcg3fdW-bS8m2eB4StGFnSPeKF_WoV68RKMUfO6QV6o1-KwhVKk8icUeKUslfKB8BS8FF6yNNZzVnQswjsEhDDC39nxqtSOHKru5N6OLJ-GhQMBH5q-fe5gd7yIH8K1e_Oz9PrtQ",
#                     "width": 2160
#                 }
#             ],
#             "place_id": "ChIJpTyVOoVe1GsRuEyYJpnYmu0",
#             "plus_code": {
#                 "compound_code": "W7PM+MC Richmond Hill QLD, Australia",
#                 "global_code": "5RF8W7PM+MC"
#             },
#             "rating": 4.4,
#             "reference": "ChIJpTyVOoVe1GsRuEyYJpnYmu0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 43,
#             "vicinity": "94 Doctor George Ellis Drive, Richmond Hill"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0724201,
#                     "lng": 146.2585754
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0709355197085,
#                         "lng": 146.2598697302915
#                     },
#                     "southwest": {
#                         "lat": -20.0736334802915,
#                         "lng": 146.2571717697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Waverley Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112116438143575835946\">Shane Lidden</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhquqHl7JaUQbm_7IdscLvTym9gcBDxGCGCu4ZTJgz9ZAJ20ZPsisLS5Fc2-70u5gd0mqdD1fraKKoMiioYIFIF_NFZ76bx1W6AvxFiFyP4nnLpDaDocektUYTblTC7X0EhCxofif5INQZhkhs2Po_VD9GhTw2AQqccGQVex2s_F0mEg2rFgv6Q",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJhZVrslBe1GsRI2zK-bD_Z9Y",
#             "plus_code": {
#                 "compound_code": "W7H5+2C Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7H5+2C"
#             },
#             "rating": 4.2,
#             "reference": "ChIJhZVrslBe1GsRI2zK-bD_Z9Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 57,
#             "vicinity": "19 Mosman Street, Lissner"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0771713,
#                     "lng": 146.270111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0759460197085,
#                         "lng": 146.2714226302915
#                     },
#                     "southwest": {
#                         "lat": -20.0786439802915,
#                         "lng": 146.2687246697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Enterprise Hotel Motel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113777859222967544857\">Mathew Furse</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAkVDQ9IxBNLZPM4ndsQLySFe4Nx8KiIoLvRmkuj39MPP_hDuD1M1bTLgfPwkNHQUufuzCF0tYzxglSGuDwt0PSmkn9hCuwL-NlpUso3GdTkykk4JinKkc5vGEiNpUySvmEhC3J2Uq6Tbfc6ShLcnW1BuxGhQsm_5ijPq0h-SIQ1g2IF2jXIomQg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJWQBLgl1e1GsRsWAJDm8wmmo",
#             "plus_code": {
#                 "compound_code": "W7FC+42 Queenton QLD, Australia",
#                 "global_code": "5RF8W7FC+42"
#             },
#             "rating": 4.4,
#             "reference": "ChIJWQBLgl1e1GsRsWAJDm8wmmo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 103,
#             "vicinity": "217 Gill Street, Queenton"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.057267,
#                     "lng": 146.255579
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0558398697085,
#                         "lng": 146.2575869302915
#                     },
#                     "southwest": {
#                         "lat": -20.0585378302915,
#                         "lng": 146.2548889697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Dalrymple Tourist Van Park",
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103320856274881910487\">Lynda Ross</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARO-Kw1THhxJIYiHWaVZi5uYu-5vcaLkgsU3V5aGi2qRnjv-3KhtQNtJzVFec9wCETEZ4QJFtY-1dCrzXRRFWjry8iD4fFfiH09uTTHok12jjsYvB5Gd8gKxodPATP4M4EhD9nCI9BCSfRGX-cnfwaZygGhT621_Ki4y_fKl9Kg97M5E_SVsOiA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJS0vZPfte1GsRKeE8tFcasXU",
#             "plus_code": {
#                 "compound_code": "W7V4+36 Toll QLD, Australia",
#                 "global_code": "5RF8W7V4+36"
#             },
#             "rating": 4.5,
#             "reference": "ChIJS0vZPfte1GsRKeE8tFcasXU",
#             "scope": "GOOGLE",
#             "types": [
#                 "rv_park",
#                 "lodging",
#                 "park",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 198,
#             "vicinity": "24 Dalrymple Road, Toll"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.067349,
#                     "lng": 146.260092
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0658094197085,
#                         "lng": 146.2613474302915
#                     },
#                     "southwest": {
#                         "lat": -20.0685073802915,
#                         "lng": 146.2586494697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Charters Towers Motel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117578047237149012280\">Charters Towers Motel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAArig-pUMkjynxz8JeEfTwq5u7Ae95dW85b1l9nMRDDuFcKW66kUoAZXuqL_Lc-VkNaj5mpJ5uy_QiSf1P7TIOvoYTOhefE_PUHbrUmb6J-g3eL7EGmzx5AiTnctshcr0jEhCkjwrMyCGmfieiYMM4LqNEGhSrkDb6yV2IByFl7F5zsEOccZA6Rw",
#                     "width": 1624
#                 }
#             ],
#             "place_id": "ChIJwXYz_fde1GsRLS8nzrgbcCM",
#             "plus_code": {
#                 "compound_code": "W7M6+32 Richmond Hill QLD, Australia",
#                 "global_code": "5RF8W7M6+32"
#             },
#             "rating": 4,
#             "reference": "ChIJwXYz_fde1GsRLS8nzrgbcCM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 64,
#             "vicinity":
charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7F6+63"
#             },
#             "reference": "ChIJFyVBN9tf1GsR1cug4Hg2dQM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "QLD"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0786577,
#                     "lng": 146.2560814
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0772764697085,
#                         "lng": 146.2573489802915
#                     },
#                     "southwest": {
#                         "lat": -20.0799744302915,
#                         "lng": 146.2546510197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Commercial Hotel",
#             "photos": [
#                 {
#                     "height": 3036,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109421425523611101343\">Lyndon Summers</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHdq6hTn5ABRTfoQ17L-eGTDp-Ijj9o2BemqQjmBBNl0XtjZjfIEF-PPmJwlpuDW4GqcVZusSJRqYl8mBCbwqt4bs6Z-179zJPXHAjaMGFl4PnGzWPzMlQk3JQW5eXVLdEhDlEhVk56EcgpnvnxCDhBGIGhTZxCRFkt9gCgwbO7VSdJel8lL3og",
#                     "width": 4048
#                 }
#             ],
#             "place_id": "ChIJV9J1RU5e1GsRZVO7xoORCUo",
#             "plus_code": {
#                 "compound_code": "W7C4+GC Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7C4+GC"
#             },
#             "rating": 3.7,
#             "reference": "ChIJV9J1RU5e1GsRZVO7xoORCUo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "151 Mosman Street, Lissner"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.077163,
#                     "lng": 146.25672
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.07578661970849,
#                         "lng": 146.2579975302915
#                     },
#                     "southwest": {
#                         "lat": -20.0784845802915,
#                         "lng": 146.2552995697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Crown Hotel",
#             "place_id": "ChIJRWdAnRhf1GsRFlccUYg0mGs",
#             "plus_code": {
#                 "compound_code": "W7F4+4M Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7F4+4M"
#             },
#             "reference": "ChIJRWdAnRhf1GsRFlccUYg0mGs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "119 Mosman Street, Charters Towers City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0762348,
#                     "lng": 146.2830505
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.07505131970849,
#                         "lng": 146.2843637302915
#                     },
#                     "southwest": {
#                         "lat": -20.0777492802915,
#                         "lng": 146.2816657697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Kernow Charters Towers",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1944,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105492832703562680312\">Stenna Jackson</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnojGhJm_mN8Vy09s9pqf7tGowUL4dQ9T8H6q6ej2BNqndQUnshGmhXQQ9AfXISvSkoocUW2nUHfkWGAr65V4U81TgbaZuIcvWayMbt2Llf5fC0bb47MvnfJgT1lcVtx4EhALrmxItG0hqbKnu_sRd_uZGhQtLxGNEuVTll4d1JapszW68lSdcw",
#                     "width": 2592
#                 }
#             ],
#             "place_id": "ChIJUzDgl2Re1GsR64OlWTLuPRo",
#             "plus_code": {
#                 "compound_code": "W7FM+G6 Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7FM+G6"
#             },
#             "rating": 5,
#             "reference": "ChIJUzDgl2Re1GsR64OlWTLuPRo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 59,
#             "vicinity": "23 -33 Gladstone Rd, Charters Towers City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.07491,
#                     "lng": 146.25774
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0735108697085,
#                         "lng": 146.2589330802915
#                     },
#                     "southwest": {
#                         "lat": -20.0762088302915,
#                         "lng": 146.2562351197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "The Rix",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115584026209367308098\">Noel Jesberg</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAR_H7rElX_ofILjCm6oCSbYG2iJq9vNEObLmbLFA_SCkqgosUSU_o77UUsvuUjGtqGYaJ7ALCqDdm7qzMaG1vHmDub1D00PE-WiGQzlSmj3FEfVylYsPi-n0025dL-T8vEhAJRHp_Z7iZ2bxQgZU-MLS7GhStDVgz1hBhlj0Xh0tZvvu7HDSRPw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJFQUgX1Be1GsRQY6JJnvniwk",
#             "plus_code": {
#                 "compound_code": "W7G5+23 Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7G5+23"
#             },
#             "rating": 4.3,
#             "reference": "ChIJFQUgX1Be1GsRQY6JJnvniwk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 58,
#             "vicinity": "69 Mosman Street, Charters Towers City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.07239,
#                     "lng": 146.266841
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0710179697085,
#                         "lng": 146.2683223302915
#                     },
#                     "southwest": {
#                         "lat": -20.0737159302915,
#                         "lng": 146.2656243697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Jupiter Mossman Night Shelter",
#             "place_id": "ChIJd8Hr7l5e1GsRtnG134G7n8Q",
#             "plus_code": {
#                 "compound_code": "W7H8+2P Queenton QLD, Australia",
#                 "global_code": "5RF8W7H8+2P"
#             },
#             "rating": 3,
#             "reference": "ChIJd8Hr7l5e1GsRtnG134G7n8Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "6 Vulture Street, Queenton"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0622735,
#                     "lng": 146.2740588
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0607194197085,
#                         "lng": 146.2754323302915
#                     },
#                     "southwest": {
#                         "lat": -20.0634173802915,
#                         "lng": 146.2727343697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Hillview Motel - Motel In Richmond Hill | Best Budget Motel | Traditional Style",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109745513978599782349\">Hillview Motel - Motel In Richmond Hill | Best Budget Motel | Traditional Style</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3lq0Hc-Z2e9oleHOJn53MNvpTXJ-pd03NJRYwcW16olG_R99u2Kal73c7oJatKWxmk4OJwE6dHn05KhUPohM8xAMu8ofWaMvRuF6OKFHd8XcZi_G1CKe7G21ldPTLx_-EhBEn1IYDW1LXjAmCfab1JqnGhTW7dtWHZjnXeM1fYWYNg55g26vlA",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJo6DXpI1e1GsRqE52n3kxGuY",
#             "plus_code": {
#                 "compound_code": "W7QF+3J Charters Towers City QLD, Australia",
#                 "global_code": "5RF8W7QF+3J"
#             },
#             "rating": 4.6,
#             "reference": "ChIJo6DXpI1e1GsRqE52n3kxGuY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 45,
#             "vicinity": "3A Hackett Terrace, Charters Towers City"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.0582378,
#                     "lng": 146.25585
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.0568085197085,
#                         "lng": 146.2577917802915
#                     },
#                     "southwest": {
#                         "lat": -20.0595064802915,
#                         "lng": 146.2550938197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Affordable Gold City Motel",
#             "photos": [
#                 {
#                     "height": 460,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104960875510622461064\">Affordable Gold City Motel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8KM0q3QqzSuH2ktB5uinOEVJWoQ8NixQV4cZ0pETXdgrU0PUKiOkRlV641MIpkBNwr5IuUb3z1CvFB5Z24R7caL5c07KR9iQijksRmt_rTyfkjill8bYb0dswTUuu64tEhC-1-LnWNg1kCwmy_L18yuVGhQYjZHZfwvNK6O07B_NHfCI3oQzcg",
#                     "width": 840
#                 }
#             ],
#             "place_id": "ChIJrQ8QD_te1GsR3XlyIP42OSs",
#             "plus_code": {
#                 "compound_code": "W7R4+P8 Toll QLD, Australia",
#                 "global_code": "5RF8W7R4+P8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJrQ8QD_te1GsR3XlyIP42OSs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "28 Dalrymple Road, Toll"
#         }
#     ],
#     "status": "OK"
# }

# %%
nearest_hotel.head()
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 39               Tessalit         20.20           1.01            87.42
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long  \
# 32             37             16.11              20  (-35.35, 150.47)
# 39             16              8.66               0      (20.2, 1.01)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)
#
#                                Nearest_Hotel  Global_Code
# 32                           Sandpiper Motel  4RPGJFXG+87
# 39
# 92     Hampton Inn & Suites Pueblo-Southgate  85CQ698G+P6
# 130                                 ホテル コラソン  8Q6J8JW5+Q3
# 157  Hotel Fairmont Makkah Clock Royal Tower  7GHXCR9G+66

# %%
# Dropping Tessalit since no hotel is found
nan_value = float("NaN")
nearest_hotel.replace("", nan_value, inplace=True)
nearest_hotel.dropna()
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
# 160                Safaga         26.73          33.94            86.00
# 186                Shingū         33.73         135.98            78.80
# 203                 Seoul         37.57         126.98            70.88
# 207               Parambu         -6.21         -40.69            75.49
# 217                Hikari         33.95         131.95            73.40
# 247         Makakilo City         21.35        -158.09            84.29
# 270             San Ramon         37.78        -121.98            77.67
# 290             Elk Point         42.68         -96.68            70.68
# 293          Batemans Bay        -35.72         150.18            84.00
# 299              Buraidah         26.33          43.98            75.20
# 348                 Maţāy         28.42          30.78            75.72
# 352             Mount Isa        -20.73         139.50            96.80
# 381          Port Hedland        -20.32         118.57            78.80
# 400                 Bilma         18.69          12.92            85.60
# 455              Karratha        -20.74         116.85            79.70
# 481                Laguna         38.42        -121.42            81.07
# 483               Winslow         35.02        -110.70            82.40
# 493          Saint George         37.10        -113.58            89.29
# 496       Charters Towers        -20.10         146.27            87.89
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long  \
# 32             37             16.11              20  (-35.35, 150.47)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)
# 160            45             11.41               0    (26.73, 33.94)
# 186            47              5.82              20   (33.73, 135.98)
# 203            46              2.89               1   (37.57, 126.98)
# 207            42              5.55              12   (-6.21, -40.69)
# 217            49              9.17              20   (33.95, 131.95)
# 247            48              9.17              40  (21.35, -158.09)
# 270            30             10.29               1  (37.78, -121.98)
# 290            49             10.00              47   (42.68, -96.68)
# 293            37              3.00               0  (-35.72, 150.18)
# 299            33              6.93               0    (26.33, 43.98)
# 348            48             11.43               0    (28.42, 30.78)
# 352            26             12.75               7   (-20.73, 139.5)
# 381             9             21.92               0  (-20.32, 118.57)
# 400            27              3.96               0    (18.69, 12.92)
# 455            17             18.39               0  (-20.74, 116.85)
# 481            41              6.64               1  (38.42, -121.42)
# 483            19              5.82               1   (35.02, -110.7)
# 493            14              9.17               1   (37.1, -113.58)
# 496            35             13.15               0   (-20.1, 146.27)
#
#                                          Nearest_Hotel  Global_Code
# 32                                     Sandpiper Motel  4RPGJFXG+87
# 92               Hampton Inn & Suites Pueblo-Southgate  85CQ698G+P6
# 130                                           ホテル コラソン  8Q6J8JW5+Q3
# 157            Hotel Fairmont Makkah Clock Royal Tower  7GHXCR9G+66
# 160                              Lamar Resort Abu Soma  7GRMQW7W+F9
# 186                                    Shingu UI Hotel  8Q5QPXFR+3J
# 203                                  LOTTE HOTEL SEOUL  8Q98HX8J+49
# 207                         Hotel pousada santo onofre  685XQ8P5+GC
# 217                                             ホテル松原屋  8Q5HXWC8+R4
# 247                     Marriott's Ko Olina Beach Club  73H38VJH+PF
# 270                                 San Ramon Marriott  849WQ27M+5W
# 290                                      Hometowne Inn  86J5M8R4+H4
# 293                         Batemans Bay Marina Resort  4RPG75JR+V8
# 299                             Mövenpick Hotel Qassim  7HR59X59+45
# 348                                         Nag Aespen  7GWGCPFM+8X
# 352                          ibis Styles Mt Isa Verona  5QFX7FFV+G4
# 381                                The Esplanade Hotel  5PFWMHPG+CC
# 400                         Expeditions Ténére voyages  7FCJMWV9+53
# 455                               ibis Styles Karratha  5PFR7R9W+4M
# 481  Holiday Inn Express & Suites Elk Grove Central...  84CWCJF2+JG
# 483                      Best Western Plus Winslow Inn  857F289H+W4
# 493                        Best Western Plus Abbey Inn  85983CQ8+J7
# 496                         Cattleman's Rest Motor Inn  5RF8W7J6+W6

# %%
# Humidity heat map
humidity = weather["Humidity (%)"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Adding the markers


# Customize the size of the figure
figure_layout = {
    'width': '1200px',
    'height': '800px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)


# Getting coordinates of the hotels
nearest_lat_long = list(nearest_hotel['Lat_Long'])
nearest_lat_long

# Assigning the markets
markers = gmaps.marker_layer(nearest_lat_long)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='800px', margin='0 auto 0 auto', padding='1px', wi…

# %%
nearest_hotel['Country'] = ""
nearest_hotel
# Out:
#                      Name  Latitude (°)  Longitude (°)  Temperature (F)  \
# 32              Ulladulla        -35.35         150.47            79.05
# 39               Tessalit         20.20           1.01            87.42
# 92                 Pueblo         38.25        -104.61            73.47
# 130                Kumano         34.34         132.59            74.28
# 157  Makkah al Mukarramah         21.43          39.83            82.98
# 160                Safaga         26.73          33.94            86.00
# 186                Shingū         33.73         135.98            78.80
# 203                 Seoul         37.57         126.98            70.88
# 207               Parambu         -6.21         -40.69            75.49
# 217                Hikari         33.95         131.95            73.40
# 247         Makakilo City         21.35        -158.09            84.29
# 270             San Ramon         37.78        -121.98            77.67
# 290             Elk Point         42.68         -96.68            70.68
# 293          Batemans Bay        -35.72         150.18            84.00
# 299              Buraidah         26.33          43.98            75.20
# 348                 Maţāy         28.42          30.78            75.72
# 352             Mount Isa        -20.73         139.50            96.80
# 381          Port Hedland        -20.32         118.57            78.80
# 400                 Bilma         18.69          12.92            85.60
# 455              Karratha        -20.74         116.85            79.70
# 481                Laguna         38.42        -121.42            81.07
# 483               Winslow         35.02        -110.70            82.40
# 493          Saint George         37.10        -113.58            89.29
# 496       Charters Towers        -20.10         146.27            87.89
#
#      Humidity (%)  Wind Speed (mph)  Cloudiness (%)          Lat_Long  \
# 32             37             16.11              20  (-35.35, 150.47)
# 39             16              8.66               0      (20.2, 1.01)
# 92             33              4.70               1  (38.25, -104.61)
# 130            49              6.93              20   (34.34, 132.59)
# 157            34              3.29               0    (21.43, 39.83)
# 160            45             11.41               0    (26.73, 33.94)
# 186            47              5.82              20   (33.73, 135.98)
# 203            46              2.89               1   (37.57, 126.98)
# 207            42              5.55              12   (-6.21, -40.69)
# 217            49              9.17              20   (33.95, 131.95)
# 247            48              9.17              40  (21.35, -158.09)
# 270            30             10.29               1  (37.78, -121.98)
# 290            49             10.00              47   (42.68, -96.68)
# 293            37              3.00               0  (-35.72, 150.18)
# 299            33              6.93               0    (26.33, 43.98)
# 348            48             11.43               0    (28.42, 30.78)
# 352            26             12.75               7   (-20.73, 139.5)
# 381             9             21.92               0  (-20.32, 118.57)
# 400            27              3.96               0    (18.69, 12.92)
# 455            17             18.39               0  (-20.74, 116.85)
# 481            41              6.64               1  (38.42, -121.42)
# 483            19              5.82               1   (35.02, -110.7)
# 493            14              9.17               1   (37.1, -113.58)
# 496            35             13.15               0   (-20.1, 146.27)
#
#                                          Nearest_Hotel  Global_Code Country
# 32                                     Sandpiper Motel  4RPGJFXG+87
# 39                                                 NaN          NaN
# 92               Hampton Inn & Suites Pueblo-Southgate  85CQ698G+P6
# 130                                           ホテル コラソン  8Q6J8JW5+Q3
# 157            Hotel Fairmont Makkah Clock Royal Tower  7GHXCR9G+66
# 160                              Lamar Resort Abu Soma  7GRMQW7W+F9
# 186                                    Shingu UI Hotel  8Q5QPXFR+3J
# 203                                  LOTTE HOTEL SEOUL  8Q98HX8J+49
# 207                         Hotel pousada santo onofre  685XQ8P5+GC
# 217                                             ホテル松原屋  8Q5HXWC8+R4
# 247                     Marriott's Ko Olina Beach Club  73H38VJH+PF
# 270                                 San Ramon Marriott  849WQ27M+5W
# 290                                      Hometowne Inn  86J5M8R4+H4
# 293                         Batemans Bay Marina Resort  4RPG75JR+V8
# 299                             Mövenpick Hotel Qassim  7HR59X59+45
# 348                                         Nag Aespen  7GWGCPFM+8X
# 352                          ibis Styles Mt Isa Verona  5QFX7FFV+G4
# 381                                The Esplanade Hotel  5PFWMHPG+CC
# 400                         Expeditions Ténére voyages  7FCJMWV9+53
# 455                               ibis Styles Karratha  5PFR7R9W+4M
# 481  Holiday Inn Express & Suites Elk Grove Central...  84CWCJF2+JG
# 483                      Best Western Plus Winslow Inn  857F289H+W4
# 493                        Best Western Plus Abbey Inn  85983CQ8+J7
# 496                         Cattleman's Rest Motor Inn  5RF8W7J6+W6

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in nearest_hotel.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    # update address key value
    global_code = row['Global_Code']
    params['address'] = global_code

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    # print(cities_lat_lng.url)
    
    # convert to json
    cities_lat_lng = cities_lat_lng.json()

    nearest_hotel.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    nearest_hotel.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-dd24bbaa1eb6> in <module>
#      19     cities_lat_lng = cities_lat_lng.json()
#      20
# ---> 21     nearest_hotel.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
#      22     nearest_hotel.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]
#      23
#
# IndexError: list index out of range

# %% [raw]
# nearest_hotel.head(5)

# %%
nearest_hotel.head(5)

# %%
# params dictionary to update each iteration
params = {
    "radius": 5000,
    "types": "hotel",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    name_address = name_address.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
